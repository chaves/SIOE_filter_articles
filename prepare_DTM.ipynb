# %%
import pandas as pd
from ftfy import fix_text # Fix unicode issues
import csv
import re
import spacy
import gensim
from gensim import corpora, utils
from gensim.models.wrappers.dtmmodel import DtmModel
from gensim.corpora import Dictionary

# %%
CURSOR = 4
ARTICES_SELECT = f'./output/select/SIOE_journals_1998_2019_{CURSOR}.pickle'
ARTICES_SELECT_CLEAN = f'./output/select/SIOE_journals_1998_2019_{CURSOR}_clean.pickle'
GB_US_synonyms = './sources/gb-us-synonyms.txt'
noisy_pos_tags = ["PROP","DET","PART","CCONJ","ADP","PRON","VERB","ADJ"]
# DET  = definite or indefinite article
# ADP  = conjunction, subordinating or preposition
# PART = adverb, particle
# ADP  = postposition => in
# PRON = pronoun, personal => I
# VERB, ADJ
min_token_length = 3 # only words <= min_token_length

# %%
df = pd.read_pickle(ARTICES_SELECT)

# %%
df.head(2)
# Out:
#      id                    review  year  \
# 1  4405  American Economic Review  2019
# 3  4461  American Economic Review  2019
#
#                                                title  \
# 1  A Macroeconomic Model of Price Swings in the H...
# 3                        A Spatial Knowledge Economy
#
#                                             keywords  \
# 1  Credit; Finance; Financial Market; Housing; Ma...
# 3                             Cities; Skill; Spatial
#
#                                             abstract
# 1  This paper shows that a macro model with segme...
# 3  Leading empiricists and theorists of cities ha...

# %%
# df.groupby(['year']).size()

# %%
df['title_abstract_keys'] = df['title'] + ' ' + df['abstract'] + ' ' + df['keywords']

# %%
# df['title_abstract'][1]

# %%
def is_noise(token):
    '''
    standard way to validate spacy tokens
    This method validate all the passed tokens and set true false on it
    '''
    is_noise = False
    if token.pos_ in noisy_pos_tags:
        is_noise = True 
    elif token.is_stop == True:
        is_noise = True
    elif token.is_digit == True:
        is_noise = True
    elif token.is_punct == True:
        is_noise = True
    elif token.is_space == True:
        is_noise = True
    elif len(token.string) <= min_token_length:
        is_noise = True
    return is_noise

# %%
nlp = spacy.load('en_core_web_sm')

# %%
my_stop_words = ['abstract', 'article', 'paper', 'effect', 'find', 'iii', 'e.g.', 'i.e.', 'al.', 'evidence', \
                 'result', 'results', 'author', 'authors', 'v.s.']
for stop in my_stop_words:
    nlp.vocab[stop].is_stop = True

# %%
def get_list(file): 
    with open(file, mode='r') as file:
        terms = csv.reader(file)
        return {rows[0]:rows[1] for rows in terms}

# %%
def gb_to_us(words):
    '''
    Replace British English with American English
    Important since it concerns an international conference
    e.g. both organisation and organization terms are used regularly
    source : https://github.com/7digital/synonym-list/
    '''
    gb_us = get_list(GB_US_synonyms)
    output = list()
    words = words.split()
    for w in words:
        if w in gb_us:
            # print(w)
            w = gb_us[w]
        output.append(w)
    return ' '.join(output)

# %%
punctuation_to_space = lambda tweet: re.sub(r"[(){}\"'’,.;@#?!&%$/\\]+\ *", " ", tweet)

# %%
article = []
texts = {}
for index, row in df.iterrows():
    words = str(row['title_abstract_keys'])
    words = fix_text(words)
    words = words.lower()
    words = punctuation_to_space(words)
    words = gb_to_us(words)
    words = " ".join(words.split()) # remove multiplple spaces and line breaks
    if(len(words.split()) >= 30): # Only title + abstract with at least 30 words 
        nlp_words = nlp(words)
        for word in nlp_words:
            if not is_noise(word):
                article.append(word.lemma_)
        texts[row.id] = article
        article = []

# %%
def insert_in_dataframe(idd):
    return texts[idd] if idd in texts else False

# %%
df['title_abstract_keys_clean'] = df.id.apply(insert_in_dataframe)
len(df)
# Out:
# 14495

# %%
df = df[df['title_abstract_keys_clean'] != False]
len(df)
# Out:
# 13415

# %%
df.head(2)
# Out:
#      id                    review  year  \
# 1  4405  American Economic Review  2019
# 3  4461  American Economic Review  2019
#
#                                                title  \
# 1  A Macroeconomic Model of Price Swings in the H...
# 3                        A Spatial Knowledge Economy
#
#                                             keywords  \
# 1  Credit; Finance; Financial Market; Housing; Ma...
# 3                             Cities; Skill; Spatial
#
#                                             abstract  \
# 1  This paper shows that a macro model with segme...
# 3  Leading empiricists and theorists of cities ha...
#
#                                  title_abstract_keys  \
# 1  A Macroeconomic Model of Price Swings in the H...
# 3  A Spatial Knowledge Economy Leading empiricist...
#
#                            title_abstract_keys_clean
# 1  [model, price, swing, housing, market, model, ...
# 3  [knowledge, economy, empiricist, theorist, cit...

# %%
texts = list(df.title_abstract_keys_clean)

# %%
bigram = gensim.models.Phrases(texts) # create bigrams

# %%
texts = [bigram[line] for line in texts]
texts[30:35]
# Out:
# [['effect',
#   'policy',
#   'change',
#   'area',
#   'eligibility',
#   'criterion',
#   'program',
#   'job',
#   'investment',
#   'subsidy',
#   'rule',
#   'area',
#   'subsidy',
#   'variable',
#   'area',
#   'eligibility',
#   'parameter',
#   'rule',
#   'area',
#   'subsidy',
#   'significantly',
#   'job',
#   'unemployment',
#   'percentage_point',
#   'increase',
#   'investment',
#   'subsidy',
#   'increase',
#   'employment',
#   'solely',
#   'firm',
#   'company',
#   'subsidy',
#   'activity',
#   'effect',
#   'investment',
#   'employment',
#   'firm',
#   'factor_productivity',
#   'employment',
#   'firm',
#   'firm',
#   'policy',
#   'investment',
#   'subsidy',
#   'unemployment'],
#  ['strategy',
#   'choice',
#   'infinitely_prisoner',
#   'dilemma',
#   'design',
#   'reliably',
#   'subject',
#   'strategy',
#   'infinitely_prisoner',
#   'dilemma',
#   'experiment',
#   'monitoring',
#   'strategy',
#   'majority',
#   'strategy',
#   'tat',
#   'addition',
#   'strategy',
#   'systematically',
#   'parameter',
#   'game',
#   'finally',
#   'strategy',
#   'ability',
#   'strategy',
#   'method',
#   'round',
#   'round',
#   'cooperation',
#   'choice',
#   'fairly',
#   'condition',
#   'cooperation',
#   'experiment_experiment',
#   'games_prisoner',
#   'dilemma_prisoner',
#   'dilemma'],
#  ['test',
#   'design',
#   'standard',
#   'test',
#   'design',
#   'certification',
#   'standard',
#   'seller',
#   'option',
#   'information',
#   'asset',
#   'quality',
#   'equilibria',
#   'principle',
#   'test',
#   'disclosure',
#   'policy',
#   'asset',
#   'value',
#   'nondisclosure',
#   'seller',
#   'information',
#   'pass',
#   'fail',
#   'certification',
#   'test',
#   'market',
#   'planner',
#   'efficiency',
#   'deadweight',
#   'testing',
#   'cost',
#   'certification',
#   'certifier',
#   'principle',
#   'standard',
#   'testing',
#   'rate',
#   'revenue',
#   'equilibria',
#   'information',
#   'monopolist',
#   'quality'],
#  ['arrival',
#   'internet',
#   'employment',
#   'africa',
#   'internet',
#   'employment',
#   'africa',
#   'arrival',
#   'submarine',
#   'internet',
#   'cable',
#   'coast',
#   'map',
#   'cable',
#   'network',
#   'difference_difference',
#   'estimate',
#   'dataset',
#   'country',
#   'effect',
#   'employment',
#   'rate',
#   'worker',
#   'group',
#   'job_displacement',
#   'space',
#   'sample',
#   'impact',
#   'employment',
#   'skill',
#   'occupation',
#   'worker',
#   'employment',
#   'level',
#   'datum',
#   'country',
#   'entry',
#   'productivity',
#   'contribute',
#   'job_creation',
#   'income',
#   'job_creation',
#   'occupation',
#   'productivity',
#   'skill'],
#  ['cyclicality',
#   'sale',
#   'price',
#   'business_cycle',
#   'policy',
#   'implication',
#   'threshold',
#   'imputation',
#   'procedure',
#   'coibion',
#   'gorodnichenko',
#   'hong',
#   'threshold',
#   'measurement_error',
#   'outlier',
#   'variability',
#   'scheme',
#   'method',
#   'explicitly',
#   'outlier',
#   'coibion',
#   'threshold',
#   'bls',
#   'approach',
#   'price',
#   'bias',
#   'measure',
#   'price',
#   'inflation',
#   'store',
#   'switching',
#   'data',
#   'cycle',
#   'inflation',
#   'price']]

# %%
for index, text in enumerate(texts):
    df['title_abstract_keys_clean'][index] = text

# %%
df.head(5)
# Out:
#       id                    review  year  \
# 1   4405  American Economic Review  2019
# 3   4461  American Economic Review  2019
# 4   4428  American Economic Review  2019
# 7   4440  American Economic Review  2019
# 10  4562  American Economic Review  2019
#
#                                                 title  \
# 1   A Macroeconomic Model of Price Swings in the H...
# 3                         A Spatial Knowledge Economy
# 4   Alcohol and Self-Control: A Field Experiment i...
# 7                    Auctions with Limited Commitment
# 10  Bayesian Identification: A Theory for State-De...
#
#                                              keywords  \
# 1   Credit; Finance; Financial Market; Housing; Ma...
# 3                              Cities; Skill; Spatial
# 4   Earnings; Experiment; Experiments; Field Exper...
# 7                                Auction; Equilibrium
# 10  Belief; Hiring; Preference; Revealed Preferenc...
#
#                                              abstract  \
# 1   This paper shows that a macro model with segme...
# 3   Leading empiricists and theorists of cities ha...
# 4   This paper studies alcohol consumption among l...
# 7   We study the role of limited commitment in a s...
# 10  We provide a revealed preference methodology f...
#
#                                   title_abstract_keys  \
# 1   A Macroeconomic Model of Price Swings in the H...
# 3   A Spatial Knowledge Economy Leading empiricist...
# 4   Alcohol and Self-Control: A Field Experiment i...
# 7   Auctions with Limited Commitment We study the ...
# 10  Bayesian Identification: A Theory for State-De...
#
#                             title_abstract_keys_clean
# 1   [model, price, swing, housing, market, model, ...
# 3   [knowledge, economy, empiricist, theorist, cit...
# 4   [alcohol, self, control, field, experiment, in...
# 7   [auction, commitment, role, commitment, auctio...
# 10  [bayesian, identification, theory, state, util...

# %%
df.to_pickle(ARTICES_SELECT_CLEAN)
