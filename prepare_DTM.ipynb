# %%
import pandas as pd
from ftfy import fix_text # Fix unicode issues
import csv
import re
import spacy
import gensim
from gensim import corpora, utils
from gensim.models.wrappers.dtmmodel import DtmModel
from gensim.corpora import Dictionary

# %%
CURSOR = 8
ARTICES_SELECT = f'./output/select/SIOE_journals_1998_2019_{CURSOR}.pickle'
ARTICES_SELECT_CLEAN = f'./output/select/SIOE_journals_1998_2019_{CURSOR}_clean.pickle'
GB_US_synonyms = './sources/gb-us-synonyms.txt'
noisy_pos_tags = ["PROP","DET","PART","CCONJ","ADP","PRON","VERB","ADJ"]
# DET  = definite or indefinite article
# ADP  = conjunction, subordinating or preposition
# PART = adverb, particle
# ADP  = postposition => in
# PRON = pronoun, personal => I
# VERB, ADJ
min_token_length = 3 # only words <= min_token_length

# %%
df = pd.read_pickle(ARTICES_SELECT)

# %%
df.head(2)
# Out:
#      id                    review  year  \
# 5  4460  American Economic Review  2019
# 7  4440  American Economic Review  2019
#
#                                                title              keywords  \
# 5  An Economic Analysis of Privacy Protection and...                   NaN
# 7                   Auctions with Limited Commitment  Auction; Equilibrium
#
#                                             abstract
# 5  Statistical agencies face a dual mandate to pu...
# 7  We study the role of limited commitment in a s...

# %%
# df.groupby(['year']).size()

# %%
df['title_abstract_keys'] = df['title'] + ' ' + df['abstract'] + ' ' + df['keywords']

# %%
# df['title_abstract'][1]

# %%
def is_noise(token):
    '''
    standard way to validate spacy tokens
    This method validate all the passed tokens and set true false on it
    '''
    is_noise = False
    if token.pos_ in noisy_pos_tags:
        is_noise = True 
    elif token.is_stop == True:
        is_noise = True
    elif token.is_digit == True:
        is_noise = True
    elif token.is_punct == True:
        is_noise = True
    elif token.is_space == True:
        is_noise = True
    elif len(token.string) <= min_token_length:
        is_noise = True
    return is_noise

# %%
nlp = spacy.load('en_core_web_sm')

# %%
my_stop_words = ['abstract', 'article', 'paper', 'effect', 'find', 'iii', 'e.g.', 'i.e.', 'al.', 'evidence', \
                 'result', 'results', 'author', 'authors', 'v.s.']
for stop in my_stop_words:
    nlp.vocab[stop].is_stop = True

# %%
def get_list(file): 
    with open(file, mode='r') as file:
        terms = csv.reader(file)
        return {rows[0]:rows[1] for rows in terms}

# %%
def gb_to_us(words):
    '''
    Replace British English with American English
    Important since it concerns an international conference
    e.g. both organisation and organization terms are used regularly
    source : https://github.com/7digital/synonym-list/
    '''
    gb_us = get_list(GB_US_synonyms)
    output = list()
    words = words.split()
    for w in words:
        if w in gb_us:
            print(w)
            w = gb_us[w]
        output.append(w)
    return ''.join(output)

# %%
punctuation_to_space = lambda tweet: re.sub(r"[(){}\"'’,.;@#?!&%$/\\]+\ *", " ", tweet)

# %%
article = []
texts = {}
gb_us = get_list(GB_US_synonyms)
for index, row in df.iterrows():
    year = row['year']
    words = str(row['title_abstract_keys'])
    words = fix_text(words)
    words = words.lower()
    words = punctuation_to_space(words)
    words = " ".join(words.split()) # remove multiplple spavces and line breaks
    if(len(words.split()) >= 30): # Only title + abstract with at least 30 words 
        nlp_words = nlp(words)
        for word in nlp_words:
            if not is_noise(word):
                article.append(word.lemma_)
        texts[row.id] = article
        article = []

# %%
def insert_in_dataframe(idd):
    return texts[idd] if idd in texts else False

# %%
df['title_abstract_keys_clean'] = df.id.apply(insert_in_dataframe)
len(df)
# Out:
# 10683

# %%
df = df[df['title_abstract_keys_clean'] != False]
len(df)
# Out:
# 9828

# %%
df.head(2)
# Out:
#       id                    review  year                             title  \
# 7   4440  American Economic Review  2019  Auctions with Limited Commitment
# 11  4444  American Economic Review  2019              Beliefs about Gender
#
#                                              keywords  \
# 7                                Auction; Equilibrium
# 11  Belief; Experiment; Experiments; Gender; Knowl...
#
#                                              abstract  \
# 7   We study the role of limited commitment in a s...
# 11  We conduct laboratory experiments that explore...
#
#                                   title_abstract_keys  \
# 7   Auctions with Limited Commitment We study the ...
# 11  Beliefs about Gender We conduct laboratory exp...
#
#                             title_abstract_keys_clean
# 7   [auction, commitment, role, commitment, auctio...
# 11  [belief, gender, laboratory, experiment, gende...

# %%
texts = list(df.title_abstract_keys_clean)

# %%
bigram = gensim.models.Phrases(texts) # create bigrams

# %%
texts = [bigram[line] for line in texts]
texts[30:35]
# Out:
# [['wife',
#   'marriage',
#   'market',
#   'incentive',
#   'labor_market',
#   'investment',
#   'woman',
#   'career',
#   'action',
#   'action',
#   'trait',
#   'like',
#   'ambition',
#   'marriage',
#   'market',
#   'mba',
#   'student',
#   'similarly',
#   'performance',
#   'classmate',
#   'exam',
#   'problem',
#   'set',
#   'woman',
#   'participation',
#   'grade',
#   'field_experiment',
#   'student',
#   'lower',
#   'salary',
#   'willingness',
#   'hour',
#   'stake',
#   'placement',
#   'questionnaire',
#   'classmate',
#   'preference',
#   'group',
#   'response',
#   'peer',
#   'observability',
#   'experiment',
#   'effect',
#   'observability',
#   'peer',
#   'experiment_field',
#   'experiment',
#   'marriage',
#   'salary',
#   'woman'],
#  ['approach',
#   'preference',
#   'theory',
#   'version',
#   'afriat',
#   'theorem',
#   'variety',
#   'choice',
#   'environment',
#   'setting',
#   'consumer',
#   'theory',
#   'test',
#   'rationalizability',
#   'environment',
#   'set_alternative',
#   'orthant',
#   'euclidean',
#   'space',
#   'utility_function',
#   'property',
#   'environment',
#   'choice',
#   'datum',
#   'lottery',
#   'consumption',
#   'consumption',
#   'consumer',
#   'preference',
#   'preference',
#   'theory',
#   'preference',
#   'utility'],
#  ['preanalysis',
#   'plan',
#   'economic',
#   'research',
#   'paper',
#   'half',
#   'time',
#   'paper',
#   'datum',
#   'code',
#   'file',
#   'preanalysis',
#   'plan',
#   'paper',
#   'datum',
#   'datum',
#   'code',
#   'replication',
#   'file',
#   'paper',
#   'percent',
#   'file',
#   'condition',
#   'publication',
#   'paper',
#   'percent',
#   'file',
#   'paper',
#   'software',
#   'paper',
#   'percent',
#   'assistance',
#   'recommendation',
#   'replication',
#   'economics',
#   'research',
#   'economic'],
#  ['proposal',
#   'replication',
#   'proposal',
#   'incentive',
#   'replication',
#   'work',
#   'better',
#   'attention',
#   'replication',
#   'journal',
#   'replication',
#   'report',
#   'work',
#   'impact',
#   'replication',
#   'scope',
#   'second',
#   'replication',
#   'currency',
#   'profession',
#   'citation',
#   'norm',
#   'replication',
#   'work',
#   'original',
#   'incentive',
#   'replication',
#   'journal',
#   'citation',
#   'journal'],
#  ['model',
#   'market',
#   'drug',
#   'model',
#   'drug',
#   'market',
#   'datum',
#   'purchase',
#   'crack',
#   'cocaine',
#   'buyer',
#   'quality',
#   'drug_drug',
#   'quality',
#   'purity',
#   'seller',
#   'time',
#   'buyer',
#   'quality',
#   'drug',
#   'buyer',
#   'equilibrium',
#   'distribution',
#   'quality',
#   'model',
#   'drug',
#   'case',
#   'purity',
#   'purity',
#   'drug',
#   'approximately_percent',
#   'dispersion',
#   'approximately_percent',
#   'penalty',
#   'purity',
#   'affordability',
#   'drug',
#   'seller',
#   'profitability',
#   'buyer',
#   'time',
#   'buyer',
#   'drug_drug',
#   'equilibrium',
#   'quality']]

# %%
for index, text in enumerate(texts):
    df['title_abstract_keys_clean'][index] = text

# %%
df.head(5)
# Out:
#       id                    review  year  \
# 7   4440  American Economic Review  2019
# 11  4444  American Economic Review  2019
# 12  4422  American Economic Review  2019
# 17  4572  American Economic Review  2019
# 18  4426  American Economic Review  2019
#
#                                                 title  \
# 7                    Auctions with Limited Commitment
# 11                               Beliefs about Gender
# 12  Beyond Truth-Telling: Preference Estimation wi...
# 17        Crises: Equilibrium Shifts and Large Shocks
# 18  Delegated Expertise, Authority, and Communication
#
#                                              keywords  \
# 7                                Auction; Equilibrium
# 11  Belief; Experiment; Experiments; Gender; Knowl...
# 12                                         Preference
# 17  Coordination Game; Equilibrium; Games; Informa...
# 18                                        Information
#
#                                              abstract  \
# 7   We study the role of limited commitment in a s...
# 11  We conduct laboratory experiments that explore...
# 12  We propose novel approaches to estimating stud...
# 17  We study the informational events that trigger...
# 18  A decision maker needs to reach a decision and...
#
#                                   title_abstract_keys  \
# 7   Auctions with Limited Commitment We study the ...
# 11  Beliefs about Gender We conduct laboratory exp...
# 12  Beyond Truth-Telling: Preference Estimation wi...
# 17  Crises: Equilibrium Shifts and Large Shocks We...
# 18  Delegated Expertise, Authority, and Communicat...
#
#                             title_abstract_keys_clean
# 7   [auction, commitment, role, commitment, auctio...
# 11  [belief, gender, laboratory, experiment, gende...
# 12  [truth, telling, preference, estimation, schoo...
# 17  [crisis, equilibrium, shift, shock, event, equ...
# 18  [delegated, expertise, authority, communicatio...

# %%
df.to_pickle(ARTICES_SELECT_CLEAN)
